# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread('../image/sst-foyer.jpg')

plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image)

kernel = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])

inverse_image = 255 -image

cv2.imwrite('../image/inverse_image.jpg',inverse_image)

plt.subplot(1,2,2)
plt.title("Inverse Colour")
plt.imshow(inverse_image)
plt.show()
